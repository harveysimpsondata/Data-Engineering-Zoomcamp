# %%
import pandas as pd

# %%
df = pd.read_parquet('yellow_tripdata_2023-01.parquet', engine='auto')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          9.3   1.00      0.5        0.00           0.0
# 1             1          7.9   1.00      0.5        4.00           0.0
# 2             1         14.9   1.00      0.5       15.00           0.0
# 3             1         12.1   7.25      0.5        0.00           0.0
# 4             1         11.4   1.00      0.5        3.28           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                    1.0         14.30                   2.5         0.00
# 1                    1.0         16.90                   2.5         0.00
# 2                    1.0         34.90                   2.5         0.00
# 3                    1.0         20.85                   0.0         1.25
# 4                    1.0         19.68                   2.5         0.00

# %%
from sqlalchemy import create_engine

engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

engine.connect()

# %%
print(pd.io.sql.get_schema(df, name='yellow_tripdata_2023_01', con=engine))
# Out:
# CREATE TABLE yellow_tripdata_2023_01 (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
def upload_df_to_sql(df, table_name, engine, chunksize):
    """
    Upload a DataFrame to an SQL database in chunks.

    :param df: The DataFrame to upload
    :param table_name: The name of the table in the database
    :param engine: An SQLAlchemy engine connected to the database
    :param chunksize: The size of each chunk
    """
    # Split the DataFrame into chunks
    chunks = [df[i:i + chunksize] for i in range(0, df.shape[0], chunksize)]

    # Upload each chunk to the database
    for i, chunk in enumerate(chunks, start=1):
        print(f'Uploading chunk {i}/{len(chunks)}')
        chunk.to_sql(
            name=table_name,
            con=engine,
            if_exists='append',  # Add data to the table if it exists
            index=False,  # Don't write the index column
        )
        print(f'Chunk {i}/{len(chunks)} uploaded')

# %%
upload_df_to_sql(df, 'yellow_tripdata_2023_01', engine, 10000)
# Out:
# Uploading chunk 1/307
# Chunk 1/307 uploaded
# Uploading chunk 2/307
# Chunk 2/307 uploaded
# Uploading chunk 3/307
# Chunk 3/307 uploaded
# Uploading chunk 4/307
# Chunk 4/307 uploaded
# Uploading chunk 5/307
# Chunk 5/307 uploaded
# Uploading chunk 6/307
# Chunk 6/307 uploaded
# Uploading chunk 7/307
# Chunk 7/307 uploaded
# Uploading chunk 8/307
# Chunk 8/307 uploaded
# Uploading chunk 9/307
# Chunk 9/307 uploaded
# Uploading chunk 10/307
# Chunk 10/307 uploaded
# Uploading chunk 11/307
# Chunk 11/307 uploaded
# Uploading chunk 12/307
# Chunk 12/307 uploaded
# Uploading chunk 13/307
# Chunk 13/307 uploaded
# Uploading chunk 14/307
# Chunk 14/307 uploaded
# Uploading chunk 15/307
# Chunk 15/307 uploaded
# Uploading chunk 16/307
# Chunk 16/307 uploaded
# Uploading chunk 17/307
# Chunk 17/307 uploaded
# Uploading chunk 18/307
# Chunk 18/307 uploaded
# Uploading chunk 19/307
# Chunk 19/307 uploaded
# Uploading chunk 20/307
# Chunk 20/307 uploaded
# Uploading chunk 21/307
# Chunk 21/307 uploaded
# Uploading chunk 22/307
# Chunk 22/307 uploaded
# Uploading chunk 23/307
# Chunk 23/307 uploaded
# Uploading chunk 24/307
# Chunk 24/307 uploaded
# Uploading chunk 25/307
# Chunk 25/307 uploaded
# Uploading chunk 26/307
# Chunk 26/307 uploaded
# Uploading chunk 27/307
# Chunk 27/307 uploaded
# Uploading chunk 28/307
# Chunk 28/307 uploaded
# Uploading chunk 29/307
# Chunk 29/307 uploaded
# Uploading chunk 30/307
# Chunk 30/307 uploaded
# Uploading chunk 31/307
# Chunk 31/307 uploaded
# Uploading chunk 32/307
# Chunk 32/307 uploaded
# Uploading chunk 33/307
# Chunk 33/307 uploaded
# Uploading chunk 34/307
# Chunk 34/307 uploaded
# Uploading chunk 35/307
# Chunk 35/307 uploaded
# Uploading chunk 36/307
# Chunk 36/307 uploaded
# Uploading chunk 37/307
# Chunk 37/307 uploaded
# Uploading chunk 38/307
# Chunk 38/307 uploaded
# Uploading chunk 39/307
# Chunk 39/307 uploaded
# Uploading chunk 40/307
# Chunk 40/307 uploaded
# Uploading chunk 41/307
# Chunk 41/307 uploaded
# Uploading chunk 42/307
# Chunk 42/307 uploaded
# Uploading chunk 43/307
# Chunk 43/307 uploaded
# Uploading chunk 44/307
# Chunk 44/307 uploaded
# Uploading chunk 45/307
# Chunk 45/307 uploaded
# Uploading chunk 46/307
# Chunk 46/307 uploaded
# Uploading chunk 47/307
# Chunk 47/307 uploaded
# Uploading chunk 48/307
# Chunk 48/307 uploaded
# Uploading chunk 49/307
# Chunk 49/307 uploaded
# Uploading chunk 50/307
# Chunk 50/307 uploaded
# Uploading chunk 51/307
# Chunk 51/307 uploaded
# Uploading chunk 52/307
# Chunk 52/307 uploaded
# Uploading chunk 53/307
# Chunk 53/307 uploaded
# Uploading chunk 54/307
# Chunk 54/307 uploaded
# Uploading chunk 55/307
# Chunk 55/307 uploaded
# Uploading chunk 56/307
# Chunk 56/307 uploaded
# Uploading chunk 57/307
# Chunk 57/307 uploaded
# Uploading chunk 58/307
# Chunk 58/307 uploaded
# Uploading chunk 59/307
# Chunk 59/307 uploaded
# Uploading chunk 60/307
# Chunk 60/307 uploaded
# Uploading chunk 61/307
# Chunk 61/307 uploaded
# Uploading chunk 62/307
# Chunk 62/307 uploaded
# Uploading chunk 63/307
# Chunk 63/307 uploaded
# Uploading chunk 64/307
# Chunk 64/307 uploaded
# Uploading chunk 65/307
# Chunk 65/307 uploaded
# Uploading chunk 66/307
# Chunk 66/307 uploaded
# Uploading chunk 67/307
# Chunk 67/307 uploaded
# Uploading chunk 68/307
# Chunk 68/307 uploaded
# Uploading chunk 69/307
# Chunk 69/307 uploaded
# Uploading chunk 70/307
# Chunk 70/307 uploaded
# Uploading chunk 71/307
# Chunk 71/307 uploaded
# Uploading chunk 72/307
# Chunk 72/307 uploaded
# Uploading chunk 73/307
# Chunk 73/307 uploaded
# Uploading chunk 74/307
# Chunk 74/307 uploaded
# Uploading chunk 75/307
# Chunk 75/307 uploaded
# Uploading chunk 76/307
# Chunk 76/307 uploaded
# Uploading chunk 77/307
# Chunk 77/307 uploaded
# Uploading chunk 78/307
# Chunk 78/307 uploaded
# Uploading chunk 79/307
# Chunk 79/307 uploaded
# Uploading chunk 80/307
# Chunk 80/307 uploaded
# Uploading chunk 81/307
# Chunk 81/307 uploaded
# Uploading chunk 82/307
# Chunk 82/307 uploaded
# Uploading chunk 83/307
# Chunk 83/307 uploaded
# Uploading chunk 84/307
# Chunk 84/307 uploaded
# Uploading chunk 85/307
# Chunk 85/307 uploaded
# Uploading chunk 86/307
# Chunk 86/307 uploaded
# Uploading chunk 87/307
# Chunk 87/307 uploaded
# Uploading chunk 88/307
# Chunk 88/307 uploaded
# Uploading chunk 89/307
# Chunk 89/307 uploaded
# Uploading chunk 90/307
# Chunk 90/307 uploaded
# Uploading chunk 91/307
# Chunk 91/307 uploaded
# Uploading chunk 92/307
# Chunk 92/307 uploaded
# Uploading chunk 93/307
# Chunk 93/307 uploaded
# Uploading chunk 94/307
# Chunk 94/307 uploaded
# Uploading chunk 95/307
# Chunk 95/307 uploaded
# Uploading chunk 96/307
# Chunk 96/307 uploaded
# Uploading chunk 97/307
# Chunk 97/307 uploaded
# Uploading chunk 98/307
# Chunk 98/307 uploaded
# Uploading chunk 99/307
# Chunk 99/307 uploaded
# Uploading chunk 100/307
# Chunk 100/307 uploaded
# Uploading chunk 101/307
# Chunk 101/307 uploaded
# Uploading chunk 102/307
# Chunk 102/307 uploaded
# Uploading chunk 103/307
# Chunk 103/307 uploaded
# Uploading chunk 104/307
# Chunk 104/307 uploaded
# Uploading chunk 105/307
# Chunk 105/307 uploaded
# Uploading chunk 106/307
# Chunk 106/307 uploaded
# Uploading chunk 107/307
# Chunk 107/307 uploaded
# Uploading chunk 108/307
# Chunk 108/307 uploaded
# Uploading chunk 109/307
# Chunk 109/307 uploaded
# Uploading chunk 110/307
# Chunk 110/307 uploaded
# Uploading chunk 111/307
# Chunk 111/307 uploaded
# Uploading chunk 112/307
# Chunk 112/307 uploaded
# Uploading chunk 113/307
# Chunk 113/307 uploaded
# Uploading chunk 114/307
# Chunk 114/307 uploaded
# Uploading chunk 115/307
# Chunk 115/307 uploaded
# Uploading chunk 116/307
# Chunk 116/307 uploaded
# Uploading chunk 117/307
# Chunk 117/307 uploaded
# Uploading chunk 118/307
# Chunk 118/307 uploaded
# Uploading chunk 119/307
# Chunk 119/307 uploaded
# Uploading chunk 120/307
# Chunk 120/307 uploaded
# Uploading chunk 121/307
# Chunk 121/307 uploaded
# Uploading chunk 122/307
# Chunk 122/307 uploaded
# Uploading chunk 123/307
# Chunk 123/307 uploaded
# Uploading chunk 124/307
# Chunk 124/307 uploaded
# Uploading chunk 125/307
# Chunk 125/307 uploaded
# Uploading chunk 126/307
# Chunk 126/307 uploaded
# Uploading chunk 127/307
# Chunk 127/307 uploaded
# Uploading chunk 128/307
# Chunk 128/307 uploaded
# Uploading chunk 129/307
# Chunk 129/307 uploaded
# Uploading chunk 130/307
# Chunk 130/307 uploaded
# Uploading chunk 131/307
# Chunk 131/307 uploaded
# Uploading chunk 132/307
# Chunk 132/307 uploaded
# Uploading chunk 133/307
# Chunk 133/307 uploaded
# Uploading chunk 134/307
# Chunk 134/307 uploaded
# Uploading chunk 135/307
# Chunk 135/307 uploaded
# Uploading chunk 136/307
# Chunk 136/307 uploaded
# Uploading chunk 137/307
# Chunk 137/307 uploaded
# Uploading chunk 138/307
# Chunk 138/307 uploaded
# Uploading chunk 139/307
# Chunk 139/307 uploaded
# Uploading chunk 140/307
# Chunk 140/307 uploaded
# Uploading chunk 141/307
# Chunk 141/307 uploaded
# Uploading chunk 142/307
# Chunk 142/307 uploaded
# Uploading chunk 143/307
# Chunk 143/307 uploaded
# Uploading chunk 144/307
# Chunk 144/307 uploaded
# Uploading chunk 145/307
# Chunk 145/307 uploaded
# Uploading chunk 146/307
# Chunk 146/307 uploaded
# Uploading chunk 147/307
# Chunk 147/307 uploaded
# Uploading chunk 148/307
# Chunk 148/307 uploaded
# Uploading chunk 149/307
# Chunk 149/307 uploaded
# Uploading chunk 150/307
# Chunk 150/307 uploaded
# Uploading chunk 151/307
# Chunk 151/307 uploaded
# Uploading chunk 152/307
# Chunk 152/307 uploaded
# Uploading chunk 153/307
# Chunk 153/307 uploaded
# Uploading chunk 154/307
# Chunk 154/307 uploaded
# Uploading chunk 155/307
# Chunk 155/307 uploaded
# Uploading chunk 156/307
# Chunk 156/307 uploaded
# Uploading chunk 157/307
# Chunk 157/307 uploaded
# Uploading chunk 158/307
# Chunk 158/307 uploaded
# Uploading chunk 159/307
# Chunk 159/307 uploaded
# Uploading chunk 160/307
# Chunk 160/307 uploaded
# Uploading chunk 161/307
# Chunk 161/307 uploaded
# Uploading chunk 162/307
# Chunk 162/307 uploaded
# Uploading chunk 163/307
# Chunk 163/307 uploaded
# Uploading chunk 164/307
# Chunk 164/307 uploaded
# Uploading chunk 165/307
# Chunk 165/307 uploaded
# Uploading chunk 166/307
# Chunk 166/307 uploaded
# Uploading chunk 167/307
# Chunk 167/307 uploaded
# Uploading chunk 168/307
# Chunk 168/307 uploaded
# Uploading chunk 169/307
# Chunk 169/307 uploaded
# Uploading chunk 170/307
# Chunk 170/307 uploaded
# Uploading chunk 171/307
# Chunk 171/307 uploaded
# Uploading chunk 172/307
# Chunk 172/307 uploaded
# Uploading chunk 173/307
# Chunk 173/307 uploaded
# Uploading chunk 174/307
# Chunk 174/307 uploaded
# Uploading chunk 175/307
# Chunk 175/307 uploaded
# Uploading chunk 176/307
# Chunk 176/307 uploaded
# Uploading chunk 177/307
# Chunk 177/307 uploaded
# Uploading chunk 178/307
# Chunk 178/307 uploaded
# Uploading chunk 179/307
# Chunk 179/307 uploaded
# Uploading chunk 180/307
# Chunk 180/307 uploaded
# Uploading chunk 181/307
# Chunk 181/307 uploaded
# Uploading chunk 182/307
# Chunk 182/307 uploaded
# Uploading chunk 183/307
# Chunk 183/307 uploaded
# Uploading chunk 184/307
# Chunk 184/307 uploaded
# Uploading chunk 185/307
# Chunk 185/307 uploaded
# Uploading chunk 186/307
# Chunk 186/307 uploaded
# Uploading chunk 187/307
# Chunk 187/307 uploaded
# Uploading chunk 188/307
# Chunk 188/307 uploaded
# Uploading chunk 189/307
# Chunk 189/307 uploaded
# Uploading chunk 190/307
# Chunk 190/307 uploaded
# Uploading chunk 191/307
# Chunk 191/307 uploaded
# Uploading chunk 192/307
# Chunk 192/307 uploaded
# Uploading chunk 193/307
# Chunk 193/307 uploaded
# Uploading chunk 194/307
# Chunk 194/307 uploaded
# Uploading chunk 195/307
# Chunk 195/307 uploaded
# Uploading chunk 196/307
# Chunk 196/307 uploaded
# Uploading chunk 197/307
# Chunk 197/307 uploaded
# Uploading chunk 198/307
# Chunk 198/307 uploaded
# Uploading chunk 199/307
# Chunk 199/307 uploaded
# Uploading chunk 200/307
# Chunk 200/307 uploaded
# Uploading chunk 201/307
# Chunk 201/307 uploaded
# Uploading chunk 202/307
# Chunk 202/307 uploaded
# Uploading chunk 203/307
# Chunk 203/307 uploaded
# Uploading chunk 204/307
# Chunk 204/307 uploaded
# Uploading chunk 205/307
# Chunk 205/307 uploaded
# Uploading chunk 206/307
# Chunk 206/307 uploaded
# Uploading chunk 207/307
# Chunk 207/307 uploaded
# Uploading chunk 208/307
# Chunk 208/307 uploaded
# Uploading chunk 209/307
# Chunk 209/307 uploaded
# Uploading chunk 210/307
# Chunk 210/307 uploaded
# Uploading chunk 211/307
# Chunk 211/307 uploaded
# Uploading chunk 212/307
# Chunk 212/307 uploaded
# Uploading chunk 213/307
# Chunk 213/307 uploaded
# Uploading chunk 214/307
# Chunk 214/307 uploaded
# Uploading chunk 215/307
# Chunk 215/307 uploaded
# Uploading chunk 216/307
# Chunk 216/307 uploaded
# Uploading chunk 217/307
# Chunk 217/307 uploaded
# Uploading chunk 218/307
# Chunk 218/307 uploaded
# Uploading chunk 219/307
# Chunk 219/307 uploaded
# Uploading chunk 220/307
# Chunk 220/307 uploaded
# Uploading chunk 221/307
# Chunk 221/307 uploaded
# Uploading chunk 222/307
# Chunk 222/307 uploaded
# Uploading chunk 223/307
# Chunk 223/307 uploaded
# Uploading chunk 224/307
# Chunk 224/307 uploaded
# Uploading chunk 225/307
# Chunk 225/307 uploaded
# Uploading chunk 226/307
# Chunk 226/307 uploaded
# Uploading chunk 227/307
# Chunk 227/307 uploaded
# Uploading chunk 228/307
# Chunk 228/307 uploaded
# Uploading chunk 229/307
# Chunk 229/307 uploaded
# Uploading chunk 230/307
# Chunk 230/307 uploaded
# Uploading chunk 231/307
# Chunk 231/307 uploaded
# Uploading chunk 232/307
# Chunk 232/307 uploaded
# Uploading chunk 233/307
# Chunk 233/307 uploaded
# Uploading chunk 234/307
# Chunk 234/307 uploaded
# Uploading chunk 235/307
# Chunk 235/307 uploaded
# Uploading chunk 236/307
# Chunk 236/307 uploaded
# Uploading chunk 237/307
# Chunk 237/307 uploaded
# Uploading chunk 238/307
# Chunk 238/307 uploaded
# Uploading chunk 239/307
# Chunk 239/307 uploaded
# Uploading chunk 240/307
# Chunk 240/307 uploaded
# Uploading chunk 241/307
# Chunk 241/307 uploaded
# Uploading chunk 242/307
# Chunk 242/307 uploaded
# Uploading chunk 243/307
# Chunk 243/307 uploaded
# Uploading chunk 244/307
# Chunk 244/307 uploaded
# Uploading chunk 245/307
# Chunk 245/307 uploaded
# Uploading chunk 246/307
# Chunk 246/307 uploaded
# Uploading chunk 247/307
# Chunk 247/307 uploaded
# Uploading chunk 248/307
# Chunk 248/307 uploaded
# Uploading chunk 249/307
# Chunk 249/307 uploaded
# Uploading chunk 250/307
# Chunk 250/307 uploaded
# Uploading chunk 251/307
# Chunk 251/307 uploaded
# Uploading chunk 252/307
# Chunk 252/307 uploaded
# Uploading chunk 253/307
# Chunk 253/307 uploaded
# Uploading chunk 254/307
# Chunk 254/307 uploaded
# Uploading chunk 255/307
# Chunk 255/307 uploaded
# Uploading chunk 256/307
# Chunk 256/307 uploaded
# Uploading chunk 257/307
# Chunk 257/307 uploaded
# Uploading chunk 258/307
# Chunk 258/307 uploaded
# Uploading chunk 259/307
# Chunk 259/307 uploaded
# Uploading chunk 260/307
# Chunk 260/307 uploaded
# Uploading chunk 261/307
# Chunk 261/307 uploaded
# Uploading chunk 262/307
# Chunk 262/307 uploaded
# Uploading chunk 263/307
# Chunk 263/307 uploaded
# Uploading chunk 264/307
# Chunk 264/307 uploaded
# Uploading chunk 265/307
# Chunk 265/307 uploaded
# Uploading chunk 266/307
# Chunk 266/307 uploaded
# Uploading chunk 267/307
# Chunk 267/307 uploaded
# Uploading chunk 268/307
# Chunk 268/307 uploaded
# Uploading chunk 269/307
# Chunk 269/307 uploaded
# Uploading chunk 270/307
# Chunk 270/307 uploaded
# Uploading chunk 271/307
# Chunk 271/307 uploaded
# Uploading chunk 272/307
# Chunk 272/307 uploaded
# Uploading chunk 273/307
# Chunk 273/307 uploaded
# Uploading chunk 274/307
# Chunk 274/307 uploaded
# Uploading chunk 275/307
# Chunk 275/307 uploaded
# Uploading chunk 276/307
# Chunk 276/307 uploaded
# Uploading chunk 277/307
# Chunk 277/307 uploaded
# Uploading chunk 278/307
# Chunk 278/307 uploaded
# Uploading chunk 279/307
# Chunk 279/307 uploaded
# Uploading chunk 280/307
# Chunk 280/307 uploaded
# Uploading chunk 281/307
# Chunk 281/307 uploaded
# Uploading chunk 282/307
# Chunk 282/307 uploaded
# Uploading chunk 283/307
# Chunk 283/307 uploaded
# Uploading chunk 284/307
# Chunk 284/307 uploaded
# Uploading chunk 285/307
# Chunk 285/307 uploaded
# Uploading chunk 286/307
# Chunk 286/307 uploaded
# Uploading chunk 287/307
# Chunk 287/307 uploaded
# Uploading chunk 288/307
# Chunk 288/307 uploaded
# Uploading chunk 289/307
# Chunk 289/307 uploaded
# Uploading chunk 290/307
# Chunk 290/307 uploaded
# Uploading chunk 291/307
# Chunk 291/307 uploaded
# Uploading chunk 292/307
# Chunk 292/307 uploaded
# Uploading chunk 293/307
# Chunk 293/307 uploaded
# Uploading chunk 294/307
# Chunk 294/307 uploaded
# Uploading chunk 295/307
# Chunk 295/307 uploaded
# Uploading chunk 296/307
# Chunk 296/307 uploaded
# Uploading chunk 297/307
# Chunk 297/307 uploaded
# Uploading chunk 298/307
# Chunk 298/307 uploaded
# Uploading chunk 299/307
# Chunk 299/307 uploaded
# Uploading chunk 300/307
# Chunk 300/307 uploaded
# Uploading chunk 301/307
# Chunk 301/307 uploaded
# Uploading chunk 302/307
# Chunk 302/307 uploaded
# Uploading chunk 303/307
# Chunk 303/307 uploaded
# Uploading chunk 304/307
# Chunk 304/307 uploaded
# Uploading chunk 305/307
# Chunk 305/307 uploaded
# Uploading chunk 306/307
# Chunk 306/307 uploaded
# Uploading chunk 307/307
# Chunk 307/307 uploaded

# %%
# df.to_sql(
#     name=table_name,
#     con=engine,
#     if_exists='append',  # Add data to the table if it exists
#     index=False,  # Don't write the index column
#     chunksize=1000,  # Adjust this value based on your desired chunk size
# )
